# %% [markdown]
# # **Taller de Python**
# # Profesores: Catalina Bernal y José S. Ñungo

# %% [markdown]
# # Clase 1: Introducción a Python
# El objetivo de este taller es darles herramientas para que se familiaricen con los comandos básicos de Python.
#
# ¿Qué es y para qué Python?
#
# Python es un [lenguaje de programación](https://es.wikipedia.org/wiki/Lenguaje_de_programaci%C3%B3n)
# - Es el lenguaje de programación más popular del mundo.
# - Es el primero cuando se trata de temas de análisis de datos.
# - Es un lenguaje de propósito general, es decir, que se utiliza para muchas cosas como Machine Learning, Internet of things, creación de aplicaciones web, de escritorio y de móviles.
# - Open-source
# - Comunidad grande y colaborativa

# %% [markdown]
# ### Jupyter Notebook
# Los archivos de extensión *.ipynb* presentan una interfaz muy cómoda para el aprendizaje, y la colaboración. Contiene:
# - Celdas de código
# - Celdas de [markdown] (https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet) (como esta)
# - Celdas de texto crudo
# - Kernel
#
# <div class="alert alert-info">
# La documentación oficial de Jupyter está
# <a href="https://jupyter-notebook.readthedocs.io/en/stable/" class="alert-link">aquí</a>
# y puede encontrar algunos Notebooks didácticos
# <a href="https://github.com/jupyter/notebook/tree/master/docs/source/examples/Notebook" class="alert-link">aquí</a>
# .

# %% [markdown]
# ### Kernel
# El "kernel" es lo que permite que se corran cosas en python, Jupyter es una interfaz para que los bloques de código corran dentro de una consola de python, el kernel es el que conecta esta interfaz con la parte del computador que corre el código.
#
# El kernel también guarda **espacio de trabajo**, es decir todas las variables que se han declarado.
#
# Se puede reiniciar el kernel de manera rápida en la pestaña de "kernel" en el tope.

# %% [markdown]
# ## Operaciones básicas
# Realice alguna operación con los siguientes comandos
# | Operación | Resultado       |
# | --------- | --------------- |
# |    +      | Suma            |
# |    -      | Resta           |
# |    *      | Multiplicación  |
# |    /      | División        |
# |    %      | Modulo          |
# |    //     | División entera |
# |    \*\*   | Potencia        |

# %%
print("### Suma ###")
print(5 + 5)
print("### Resta ###")
print(5 - 5)
print("### Multiplicación ###")
print(3 * 5)
print("### División ###")
print(10 / 3)
print("### Divisón entera ###")
print(10 // 3)
print("### Modulo ###")
print(18 % 7)
print("### Potencia ###")
print(4 ** 2)
# Out:
# ### Suma ###
# 10
# ### Resta ###
# 0
# ### Multiplicación ###
# 15
# ### División ###
# 3.3333333333333335
# ### Divisón entera ###
# 3
# ### Modulo ###
# 4
# ### Potencia ###
# 16

# %% [markdown]
# ## Variables
# Para definir variables en Python utilizamos el simbolo de igual (`=`). Como buena práctica de programación, cuando definimos un nombre, utilizamos guión bajo (`_`) para separar las palabras. **Nunca usamos un punto** (Para los que vienen de R). Adicionalmente se debe usar caracteres especiales como tildes o ñ en los nombres de los objetos que definamos.
#
# A continuación debe crear 4 variables.
# - La primera variable se debe llamar `refran` y debe ser un texto alusivo a un refran. Hint: Todos los textos deben estar entre comillas para que Python sepa que son textos.
# - La segunda variable se debe llamar `x` y debe ser un número entero.
# - La tercera variable se debe llamar `pi` y debe ser el número pi aproximado
# - La cuarta variable se debe llamar `condicion` y debe tomar el valor de `True` o `False`

# %%
refran = "Perro que ladra no muerde"
x = 3
pi = 3.1416
condicion = True

# %%
print(x + pi)
# Out:
# 6.1416

# %% [markdown]
# ### Operadores de asignación
# 1. ¿Qué hace +=?
# 2. ¿Qué hace -=?
# 3. ¿Qué hace *=?
# 4. ¿Qué hace /=?

# %%
a = 2
b = 5
c = 7

# %% [markdown]
# b = b + 3 es equivalente a b += 3

# %%
#Este es un comentario
a -= 3
b += 3
c *= 5
c /= 8

# %% [markdown]
# ### Strings
# ¿Qué métodos tiene un string?
#
# 1. Cree un string que sea `nombre` y `apellido`. Súmelos
# 1. Multiplique por 3 la variable `nombre` e imprimala
# 1. Obtenga el número de caracteres en `nombre`
#
# * Explore los métodos de un string utilizando `tab`.

# %%
nombre= "Catalina"
apellido="Bernal"

# %%
print(nombre*3)
# Out:
# CatalinaCatalinaCatalina

# %%
nombre + apellido
# Out:
# 'CatalinaBernal'

# %%
len(nombre)
# Out:
# 8

# %%
nombre.

# %%
print(nombre.upper())
print(apellido.count('n'))
# Out:
# CATALINA
# 1

# %% [markdown]
# ### Valores Booleanos (comparar valores)
# 1. Pregunte si "a" es mayor que "b"
# 2. Pregunte si "a" es mayor o igual que "a"
# 3. Pregunte si "a" es igual a cualquier número
# 4. Pregunte si "mi_nombre" es igual a "Juan Moreno"

# %%
print(a > b)
print(a >= a)
print(a == 6)
print(nombre == 'Jose Ñungo')
# Out:
# False
# True
# False
# False

# %% [markdown]
# ----------------------

# %% [markdown]
# ## **PROGRAMANÍA**
#
# ### _Pa' divertirse._

# %% [markdown]
# ### Definiendo Variables
# 1. Defina la variable "a" como un entero cualquiera.
# 2. Defina la variable "b" como un entero cualquiera.
# 3. Defina la variable "c" como un entero cualquiera.

# %% [markdown]
# ### Operaciones Matemáticas
# Con los números se pueden realizar los siguientes tipos de operaciones:
#
# | Operación | Resultado       |
# | --------- | --------------- |
# |    +      | Suma            |
# |    -      | Resta           |
# |    *      | Multiplicación  |
# |    /      | División        |
# |    //     | División entera |
# |    \*\*   | Potencia        |
# |     %      | Residuo        |
#
# Imprima los siguientes cálculos
# 1. Divida "a" en "b".
# 2. Divida usando "//" interactue "a" en "b".
# 3. Multiplique "a" y "b".
# 4. Eleve "c" a la 3.
# 5. Calcule el residuo entre "a" y "c".

# %% [markdown]
# * Cree un string que sea `nombre` y `apellido`. Utilice los siguientes comandos y comente que hace cada uno:
#
# 1. `.replace('a','i')` NOTA: La "a" debe ser cualquier letra que esté en su nombre.
# 1. `.count('a')` NOTA: La "a" debe ser cualquier letra que esté en su nombre.
# 1. `.lower()`
# 1. `.zfill(10)` NOTA: Pruébelo con otros números.
# 1. `.swapcase()`
# 1. `.index('a')` NOTA: La "a" debe ser cualquier letra que esté en su nombre.`
# 1. `.isnumeric()`
# 1. `.startswith('a')`
# 1. `.islower()`

# %%
# Out:
# 1
